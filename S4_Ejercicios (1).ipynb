# %% [markdown]
# # SEMANA 4: Ejercicios con imágenes y video en python
#
# **Profesor: Luis Carlos Guayacán**
#
# **Auxiliar: Dylan Villalba Roa**
#
# *Semillero MLACV - Grupo BIVL2ab*

# %% [markdown]
# <br>

# %%
#Importamos las librerías necesarias
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from urllib.request import urlopen

# %% [markdown]
# Ejecute las siguientes dos celdas

# %%
# Instalamos git para Python
# !pip3 install gitpython

# %%
# Descargamos los datos necesarios para la actividad
# (Ignorar el mensaje "rm: cannot remove 'data' ...")

from git.repo.base import Repo
# !rm -r data

url = 'https://gitlab.com/luis.guayacan1/semillero_macv_2022-1.git'
Repo.clone_from(url,"data");

# %% [markdown]
# ## Ejercicio 1:

# %% [markdown]
# **a.** Lea la imagen "/content/data/S4-Activity/Histologia.jpeg" y visualícela en RGB.

# %%
# Escriba el código acá:



########################

plt.show()

# %% [markdown]
# **b.** Visualice cada uno de los canales RGB de manera independiente.

# %%
# Escriba el código acá:



########################

plt.show()

# %% [markdown]
# **c.** Visualice la imagen en escala de grises.

# %%
# Escriba el código acá:



########################

plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ## Ejercicio 2:

# %% [markdown]
# **a.** Dada la siguiente imagen en escala de grises

# %%
# Se carga una nueva imagen 
img = Image.open("/content/data/S4-Activity/Abduzcan.jpeg")

# Esta es otra forma de convertir RGB a gris:
imgGray = img.convert('L')       
plt.imshow(imgGray, cmap='gray')
plt.title("Abduzcan!");

# %% [markdown]
# Binarice la imagen de tal forma que solamente queden visibles (en blanco) las letras del letrero de neón del fondo.

# %%
# Escriba el código acá:



########################

# %% [markdown]
# **b.** Binarice la siguiente imagen de tal forma que se extraiga la silueta del fósil.

# %%
# Se carga una nueva imagen 
img = Image.open("/content/data/S4-Activity/Fosil.jpeg")

# Esta es otra forma de convertir RGB a gris:
imgGray = img.convert('L')       
plt.imshow(imgGray, cmap='gray')
plt.title("Trilobites");

# %%
# Escriba el código acá:



########################

# %% [markdown]
# <br>

# %% [markdown]
# ## Ejercicio 3:

# %% [markdown]
# Visualice el video "/content/data/S4-Activity/Video", frame por frame, usando las funciones *IntSlider* e *interactive* y responda **¿En qué frame aparece por primera vez el humo mágico?**
#
# Nota: ajustar el parámetro *step=1*

# %%
from ipywidgets import widgets, IntSlider, interactive

# Escriba el código acá:



########################

# %% [markdown]
# *El humo aparece por primera vez en el frame: __*
